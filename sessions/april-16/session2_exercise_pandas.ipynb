# %% [markdown]
# # ZAS Python Working Group — Session 2
# ## Exercise: Python Basics with Real(-ish) Data
#
# We have a small reaction time dataset: **20 participants**, each completing trials across two stimulus types (*word*, *image*) and two conditions (*congruent*, *incongruent*).
#
# Work through the cells below. Each cell tells you what to do — write your code underneath the comment.
#
# ---

# %% [markdown]
# ## Part 1 — Loading & First Look

# %%
# 1a. Import pandas

# %%
# 1b. Load 'data/reaction_times.csv' into a DataFrame called df
#     and display the first 5 rows

# %%
# 1c. How many rows and columns does the DataFrame have?
#     Hint: .shape

# %%
# 1d. Print a quick summary of the DataFrame — column names, data types, non-null counts
#     Hint: .info()

# %%
# 1e. Print basic descriptive statistics for the numeric columns
#     Hint: .describe()

# %% [markdown]
# ---
# ## Part 2 — Exploring Columns

# %%
# 2a. Print the unique values in the 'condition' column
#     How many unique conditions are there?

# %%
# 2b. Print the unique values in the 'stimulus' column

# %%
# 2c. How many unique participants are in the dataset?
#     Print their IDs.

# %%
# 2d. Count how many trials there are per participant.
#     Hint: .value_counts() on the participant_id column

# %%
# 2e. What is the overall mean, min, and max RT?

# %% [markdown]
# ---
# ## Part 3 — Filtering Rows

# %%
# 3a. Create a new DataFrame containing only the incongruent trials.
#     How many rows does it have?

# %%
# 3b. Create a DataFrame with only correct trials.
#     What proportion of all trials were correct?

# %%
# 3c. Create a DataFrame with trials where RT is greater than 0.7 s.
#     Print the participant ID, condition, and RT for each of these trials.

# %%
# 3d. Filter to trials that are BOTH incongruent AND incorrect.
#     How many are there?

# %% [markdown]
# ---
# ## Part 4 — Grouping & Summarising

# %%
# 4a. Compute mean RT for each condition (congruent vs incongruent).
#     Is the incongruent condition slower, as expected?
#     Hint: groupby()

# %%
# 4b. Compute mean RT for each stimulus type (word vs image).

# %%
# 4c. Compute mean RT for each combination of condition AND stimulus type.
#     You should get 4 rows.

# %%
# 4d. For each participant, compute:
#       - number of trials
#       - mean RT
#       - accuracy (proportion correct)
#     Store the result in a new DataFrame called 'summary'.
#     Hint: groupby() + agg()

# %%
# 4e. Sort the summary table by mean RT (fastest first) and display it.

# %% [markdown]
# ---
# ## Part 5 — Adding & Transforming Columns

# %%
# 5a. Add a new column 'rt_ms' with RT converted to milliseconds.

# %%
# 5b. Add a column 'fast_trial' that is True when RT < 0.4 s, False otherwise.
#     How many fast trials are there in total?

# %%
# 5c. Add a column 'speed' that labels each trial as:
#       'fast'   if RT < 0.35 s
#       'normal' if RT between 0.35 and 0.55 s
#       'slow'   if RT > 0.55 s
#     Hint: pd.cut()
#     Check the counts with .value_counts()

# %%
# 5d. Compute the mean RT separately for each 'speed' category
#     to verify your labels make sense.

# %% [markdown]
# ---
# ## Bonus — for fast finishers

# %%
# Bonus 1. Which participant has the highest accuracy?
#          Which has the lowest?

# %%
# Bonus 2. Is accuracy different between congruent and incongruent conditions?
#          Compute accuracy per condition.

# %%
# Bonus 3. Save the summary table from Part 4d to a CSV file.
#          Hint: .to_csv() — check the docs for how to skip the index.
