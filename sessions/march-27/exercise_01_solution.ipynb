# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Load data

# %%
df = pd.read_csv("data/scores.csv")

# %% [markdown]
# # Quick look

# %%
print("Shape:", df.shape)
print(df.head())
# Out:
# Shape: (12, 4)
#   participant_id   name  score  session
# 0            P01  Alice     72        1
# 1            P02    Bob     45        1
# 2            P03  Carol     88        1
# 3            P04  David     31        1
# 4            P05    Eva     95        1

# %% [markdown]
# # Filter rows

# %%
# Keep only rows where condition is TRUE
good_rows = df["score"] > 50        

print("Rows passing filter:", len(good_rows))
# Out:
# Rows passing filter: 12

# %% [markdown]
# # Compute summary

# %%
mean_score = df["score"].mean()
max_score  = df["score"].max()

print("Mean score:", round(mean_score, 2))      
print("Max score: ", max_score)
# Out:
# Mean score: 66.75
# Max score:  95

# %% [markdown]
# # Add a new column

# %%
type(df['score'])
# Out:
# pandas.Series

# %%
# Normalise scores to 0–1 range
df["score_norm"] = (df["score"] - df["score"].min()) / \
                   (df["score"].max() - df["score"].min())

# %% [markdown]
# # Plot

# %%
sns.histplot(data=df, x="score_norm")
# Out:
# <Axes: xlabel='score_norm', ylabel='Count'>
